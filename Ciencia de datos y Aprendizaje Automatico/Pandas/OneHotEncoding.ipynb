# %% [markdown]
# # One Hot Encoding (Pre Procesamiento de datos)
#
# La técnica One-Hot Encoding (codificación one-hot) es un método comúnmente utilizado en aprendizaje automático y procesamiento de datos para representar variables categóricas como vectores binarios. Esta técnica transforma variables categóricas en una forma que puede ser proporcionada a algoritmos de aprendizaje automático para mejorar la precisión de los modelos.
#
# Por ejemplo, supongamos que tienes una variable categórica "Fruta" con las categorías "Manzana", "Banana" y "Naranja". Aplicando One-Hot Encoding, obtendrías tres nuevas columnas: "Manzana", "Banana" y "Naranja". Cada fila en el conjunto de datos tendrá un 1 en la columna correspondiente a la fruta que representa y 0 en las otras dos columnas.

# %% [markdown]
# | Fruta  | Manzana | Banana | Naranja |
# |--------|---------|--------|---------|
# | Manzana| 1       | 0      | 0       |
# | Banana | 0       | 1      | 0       |
# | Naranja| 0       | 0      | 1       |
#
#
# La columna "Manzana" tiene un 1 donde la fruta es "Manzana" y 0 en las otras filas.
#
# La columna "Banana" tiene un 1 donde la fruta es "Banana" y 0 en las otras filas.
#
# La columna "Naranja" tiene un 1 donde la fruta es "Naranja" y 0 en las otras filas.
#
# Cada columna representa una categoría específica y muestra si esa categoría está presente o no en cada fila. No hay dependencia de una columna en función de sí misma; más bien, cada columna es independiente y refleja la presencia o ausencia de una categoría particular para cada observación en el conjunto de datos.

# %%
import pandas as pd

route=r"\Users\Cristian\PythonLogic\Media\HRDataset_v14.csv"

human=pd.read_csv(filepath_or_buffer=route)

human.head(10)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
# 5         Anderson, Linda    10002          0                0         0
# 6           Andreola, Colby  10194          0                0         0
# 7               Athwal, Sam  10062          0                4         1
# 8          Bachiochi, Linda  10114          0                0         0
# 9        Bacong, Alejandro   10250          0                2         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
# 5            1       5            4                       0   57568  ...
# 6            1       4            3                       0   95660  ...
# 7            1       5            3                       0   59365  ...
# 8            3       5            3                       1   47837  ...
# 9            1       3            3                       0   50178  ...
#
#        ManagerName  ManagerID   RecruitmentSource PerformanceScore  \
# 0   Michael Albert       22.0            LinkedIn          Exceeds
# 1       Simon Roup        4.0              Indeed      Fully Meets
# 2   Kissy Sullivan       20.0            LinkedIn      Fully Meets
# 3     Elijiah Gray       16.0              Indeed      Fully Meets
# 4   Webster Butler       39.0       Google Search      Fully Meets
# 5         Amy Dunn       11.0            LinkedIn          Exceeds
# 6  Alex Sweetwater       10.0            LinkedIn      Fully Meets
# 7    Ketsia Liebig       19.0   Employee Referral      Fully Meets
# 8   Brannon Miller       12.0  Diversity Job Fair      Fully Meets
# 9     Peter Monroe        7.0              Indeed      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
# 3              4.84               5                    0
# 4              5.00               4                    0
# 5              5.00               5                    0
# 6              3.04               3                    4
# 7              5.00               4                    0
# 8              4.46               3                    0
# 9              5.00               5                    6
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# 1                  2/24/2016              0       17
# 2                  5/15/2012              0        3
# 3                   1/3/2019              0       15
# 4                   2/1/2016              0        2
# 5                   1/7/2019              0       15
# 6                   1/2/2019              0       19
# 7                  2/25/2019              0       19
# 8                  1/25/2019              0        4
# 9                  2/18/2019              0       16
#
# [10 rows x 36 columns]

# %%
human.columns.values
# Out:
# array(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID',
#        'GenderID', 'EmpStatusID', 'DeptID', 'PerfScoreID',
#        'FromDiversityJobFairID', 'Salary', 'Termd', 'PositionID',
#        'Position', 'State', 'Zip', 'DOB', 'Sex', 'MaritalDesc',
#        'CitizenDesc', 'HispanicLatino', 'RaceDesc', 'DateofHire',
#        'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date',
#        'DaysLateLast30', 'Absences'], dtype=object)

# %%
human_table = human[["Employee_Name","Position","Salary","State", "Sex", "DOB", "MaritalDesc","CitizenDesc", "Department", "PerformanceScore"
, "EngagementSurvey", "EmpSatisfaction" ]]

human_table.head(10)
# Out:
#               Employee_Name                  Position  Salary State Sex  \
# 0       Adinolfi, Wilson  K   Production Technician I   62506    MA  M
# 1  Ait Sidi, Karthikeyan                      Sr. DBA  104437    MA  M
# 2         Akinkuolie, Sarah  Production Technician II   64955    MA   F
# 3              Alagbe,Trina   Production Technician I   64991    MA   F
# 4          Anderson, Carol    Production Technician I   50825    MA   F
# 5         Anderson, Linda     Production Technician I   57568    MA   F
# 6           Andreola, Colby         Software Engineer   95660    MA   F
# 7               Athwal, Sam   Production Technician I   59365    MA  M
# 8          Bachiochi, Linda   Production Technician I   47837    MA   F
# 9        Bacong, Alejandro                 IT Support   50178    MA  M
#
#         DOB MaritalDesc CitizenDesc            Department PerformanceScore  \
# 0  07/10/83      Single  US Citizen     Production                 Exceeds
# 1  05/05/75     Married  US Citizen                 IT/IS      Fully Meets
# 2  09/19/88     Married  US Citizen     Production             Fully Meets
# 3  09/27/88     Married  US Citizen     Production             Fully Meets
# 4  09/08/89    Divorced  US Citizen     Production             Fully Meets
# 5  05/22/77      Single  US Citizen     Production                 Exceeds
# 6  05/24/79      Single  US Citizen  Software Engineering      Fully Meets
# 7  02/18/83     Widowed  US Citizen     Production             Fully Meets
# 8  02/11/70      Single  US Citizen     Production             Fully Meets
# 9  01/07/88    Divorced  US Citizen                 IT/IS      Fully Meets
#
#    EngagementSurvey  EmpSatisfaction
# 0              4.60                5
# 1              4.96                3
# 2              3.02                3
# 3              4.84                5
# 4              5.00                4
# 5              5.00                5
# 6              3.04                3
# 7              5.00                4
# 8              4.46                3
# 9              5.00                5

# %%
human_table.describe()
# Out:
#               Salary  EngagementSurvey  EmpSatisfaction
# count     311.000000        311.000000       311.000000
# mean    69020.684887          4.110000         3.890675
# std     25156.636930          0.789938         0.909241
# min     45046.000000          1.120000         1.000000
# 25%     55501.500000          3.690000         3.000000
# 50%     62810.000000          4.280000         4.000000
# 75%     72036.000000          4.700000         5.000000
# max    250000.000000          5.000000         5.000000

# %%
dummy_variable_sex=pd.get_dummies(human_table["Sex"], prefix="sex") #Primero se crea una variable dummy para almacenar los datos, con prefix de como va a quedar esta tabla 

dummy_variable_sex.head(10)
# Out:
#    sex_F  sex_M
# 0  False    True
# 1  False    True
# 2   True   False
# 3   True   False
# 4   True   False
# 5   True   False
# 6   True   False
# 7  False    True
# 8   True   False
# 9  False    True

# %%
human_table=human_table.drop(["Sex"],axis=1) #De la tabla original se elimina la columna que vamos a pre procesar

human_table
# Out:
#                 Employee_Name                  Position  Salary State  \
# 0         Adinolfi, Wilson  K   Production Technician I   62506    MA
# 1    Ait Sidi, Karthikeyan                      Sr. DBA  104437    MA
# 2           Akinkuolie, Sarah  Production Technician II   64955    MA
# 3                Alagbe,Trina   Production Technician I   64991    MA
# 4            Anderson, Carol    Production Technician I   50825    MA
# ..                        ...                       ...     ...   ...
# 306            Woodson, Jason  Production Technician II   65893    MA
# 307        Ybarra, Catherine    Production Technician I   48513    MA
# 308          Zamora, Jennifer                       CIO  220450    MA
# 309               Zhou, Julia              Data Analyst   89292    MA
# 310             Zima, Colleen   Production Technician I   45046    MA
#
#           DOB MaritalDesc CitizenDesc         Department PerformanceScore  \
# 0    07/10/83      Single  US Citizen  Production                 Exceeds
# 1    05/05/75     Married  US Citizen              IT/IS      Fully Meets
# 2    09/19/88     Married  US Citizen  Production             Fully Meets
# 3    09/27/88     Married  US Citizen  Production             Fully Meets
# 4    09/08/89    Divorced  US Citizen  Production             Fully Meets
# ..        ...         ...         ...                ...              ...
# 306  05/11/85      Single  US Citizen  Production             Fully Meets
# 307  05/04/82      Single  US Citizen  Production                     PIP
# 308  08/30/79      Single  US Citizen              IT/IS          Exceeds
# 309  02/24/79      Single  US Citizen              IT/IS      Fully Meets
# 310  08/17/78     Widowed  US Citizen  Production             Fully Meets
#
#      EngagementSurvey  EmpSatisfaction
# 0                4.60                5
# 1                4.96                3
# 2                3.02                3
# 3                4.84                5
# 4                5.00                4
# ..                ...              ...
# 306              4.07                4
# 307              3.20                2
# 308              4.60                5
# 309              5.00                3
# 310              4.50                5
#
# [311 rows x 11 columns]

# %%
human_table2=pd.concat([human_table,dummy_variable_sex],axis=1) #Se concatena en una nueva tabla usando la original y la nueva de dummy, con axis correspondiente a las columnas

human_table2
# Out:
#                 Employee_Name                  Position  Salary State  \
# 0         Adinolfi, Wilson  K   Production Technician I   62506    MA
# 1    Ait Sidi, Karthikeyan                      Sr. DBA  104437    MA
# 2           Akinkuolie, Sarah  Production Technician II   64955    MA
# 3                Alagbe,Trina   Production Technician I   64991    MA
# 4            Anderson, Carol    Production Technician I   50825    MA
# ..                        ...                       ...     ...   ...
# 306            Woodson, Jason  Production Technician II   65893    MA
# 307        Ybarra, Catherine    Production Technician I   48513    MA
# 308          Zamora, Jennifer                       CIO  220450    MA
# 309               Zhou, Julia              Data Analyst   89292    MA
# 310             Zima, Colleen   Production Technician I   45046    MA
#
#           DOB MaritalDesc CitizenDesc         Department PerformanceScore  \
# 0    07/10/83      Single  US Citizen  Production                 Exceeds
# 1    05/05/75     Married  US Citizen              IT/IS      Fully Meets
# 2    09/19/88     Married  US Citizen  Production             Fully Meets
# 3    09/27/88     Married  US Citizen  Production             Fully Meets
# 4    09/08/89    Divorced  US Citizen  Production             Fully Meets
# ..        ...         ...         ...                ...              ...
# 306  05/11/85      Single  US Citizen  Production             Fully Meets
# 307  05/04/82      Single  US Citizen  Production                     PIP
# 308  08/30/79      Single  US Citizen              IT/IS          Exceeds
# 309  02/24/79      Single  US Citizen              IT/IS      Fully Meets
# 310  08/17/78     Widowed  US Citizen  Production             Fully Meets
#
#      EngagementSurvey  EmpSatisfaction  sex_F  sex_M
# 0                4.60                5  False    True
# 1                4.96                3  False    True
# 2                3.02                3   True   False
# 3                4.84                5   True   False
# 4                5.00                4   True   False
# ..                ...              ...    ...     ...
# 306              4.07                4  False    True
# 307              3.20                2   True   False
# 308              4.60                5   True   False
# 309              5.00                3   True   False
# 310              4.50                5   True   False
#
# [311 rows x 13 columns]

# %%
dummy_Country = pd.get_dummies(human_table["CitizenDesc"], prefix="citizen")

# Eliminar la columna original "CitizenDesc"
human_table = human_table.drop("CitizenDesc", axis=1)

# Concatenar el DataFrame original con las variables dummy
human_Table3 = pd.concat([human_table2, dummy_Country], axis=1)

human_Table3.head(20)

#El error que tuve fue que estaba trabajando en human_table2 que se le eliminaba esa tabla por lo tanto no habia donde buscar, se
#Trabajar en la original


Tarea: Hacer una funcion que automatize esto
# Out:
#                Employee_Name                  Position  Salary State  \
# 0        Adinolfi, Wilson  K   Production Technician I   62506    MA
# 1   Ait Sidi, Karthikeyan                      Sr. DBA  104437    MA
# 2          Akinkuolie, Sarah  Production Technician II   64955    MA
# 3               Alagbe,Trina   Production Technician I   64991    MA
# 4           Anderson, Carol    Production Technician I   50825    MA
# 5          Anderson, Linda     Production Technician I   57568    MA
# 6            Andreola, Colby         Software Engineer   95660    MA
# 7                Athwal, Sam   Production Technician I   59365    MA
# 8           Bachiochi, Linda   Production Technician I   47837    MA
# 9         Bacong, Alejandro                 IT Support   50178    MA
# 10      Baczenski, Rachael     Production Technician I   54670    MA
# 11           Barbara, Thomas   Production Technician I   47211    MA
# 12          Barbossa, Hector              Data Analyst   92328    TX
# 13      Barone, Francesco  A   Production Technician I   58709    MA
# 14             Barton, Nader   Production Technician I   52505    MA
# 15             Bates, Norman   Production Technician I   57834    MA
# 16          Beak, Kimberly    Production Technician II   70131    MA
# 17       Beatrice, Courtney    Production Technician I   59026    MA
# 18             Becker, Renee    Database Administrator  110000    MA
# 19             Becker, Scott   Production Technician I   53250    MA
#
#          DOB MaritalDesc            Department PerformanceScore  \
# 0   07/10/83      Single     Production                 Exceeds
# 1   05/05/75     Married                 IT/IS      Fully Meets
# 2   09/19/88     Married     Production             Fully Meets
# 3   09/27/88     Married     Production             Fully Meets
# 4   09/08/89    Divorced     Production             Fully Meets
# 5   05/22/77      Single     Production                 Exceeds
# 6   05/24/79      Single  Software Engineering      Fully Meets
# 7   02/18/83     Widowed     Production             Fully Meets
# 8   02/11/70      Single     Production             Fully Meets
# 9   01/07/88    Divorced                 IT/IS      Fully Meets
# 10  01/12/74     Married     Production             Fully Meets
# 11  02/21/74     Married     Production             Fully Meets
# 12  07/04/88    Divorced                 IT/IS          Exceeds
# 13  07/20/83      Single     Production             Fully Meets
# 14  07/15/77    Divorced     Production             Fully Meets
# 15  10/18/81      Single     Production             Fully Meets
# 16  04/17/66     Married     Production                 Exceeds
# 17  10/27/70      Single     Production             Fully Meets
# 18  04/04/86      Single                 IT/IS      Fully Meets
# 19  04/06/79      Single     Production             Fully Meets
#
#     EngagementSurvey  EmpSatisfaction  sex_F  sex_M   \
# 0               4.60                5  False    True
# 1               4.96                3  False    True
# 2               3.02                3   True   False
# 3               4.84                5   True   False
# 4               5.00                4   True   False
# 5               5.00                5   True   False
# 6               3.04                3   True   False
# 7               5.00                4  False    True
# 8               4.46                3   True   False
# 9               5.00                5  False    True
# 10              4.20                4   True   False
# 11              4.20                3  False    True
# 12              4.28                4  False    True
# 13              4.60                4  False    True
# 14              5.00                5  False    True
# 15              5.00                4  False    True
# 16              4.40                3   True   False
# 17              5.00                5   True   False
# 18              4.50                4   True   False
# 19              4.20                4  False    True
#
#     citizen_Eligible NonCitizen  citizen_Non-Citizen  citizen_US Citizen
# 0                         False                False                True
# 1                         False                False                True
# 2                         False                False                True
# 3                         False                False                True
# 4                         False                False                True
# 5                         False                False                True
# 6                         False                False                True
# 7                         False                False                True
# 8                         False                False                True
# 9                         False                False                True
# 10                        False                False                True
# 11                        False                False                True
# 12                        False                False                True
# 13                        False                False                True
# 14                        False                False                True
# 15                        False                False                True
# 16                        False                False                True
# 17                         True                False               False
# 18                        False                False                True
# 19                        False                False                True

# %%
human_table2.columns
# Out:
# Index(['Employee_Name', 'Position', 'Salary', 'State', 'DOB', 'MaritalDesc',
#        'Department', 'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'sex_F', 'sex_M '],
#       dtype='object')
